# %% [markdown]
# <a href="https://www.kaggle.com/code/lupevazquez/global-hack-week-lupe-vazquez?scriptVersionId=158488328" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Hello, World!

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # Sorting Method

# %%
instruments = ['Guitar', 'Bass', 'Drums', 'Keyboard', 'Saxophone', 'Trumpet']

# %%
# sorted by alphabetical order
sorted(instruments)
# Out:
# ['Bass', 'Drums', 'Guitar', 'Keyboard', 'Saxophone', 'Trumpet']

# %% [markdown]
# #  Build a Rock, Paper, Scissors Game

# %%
import random

while True:
    user_action = input("Enter a choice (rock, paper, scissors): ")
    possible_actions = ["rock", "paper", "scissors"]
    computer_action = random.choice(possible_actions)
    print(f"\nYou chose {user_action}, computer chose {computer_action}.\n")

    if user_action == computer_action:
        print(f"Both players selected {user_action}. It's a tie!")
    elif user_action == "rock":
        if computer_action == "scissors":
            print("Rock smashes scissors! You win! :)")
        else:
            print("Paper covers rock! You lose. :(")
    elif user_action == "paper":
        if computer_action == "rock":
            print("Paper covers rock! You win! :)")
        else:
            print("Scissors cuts paper! You lose. :(")
    elif user_action == "scissors":
        if computer_action == "paper":
            print("Scissors cuts paper! You win! :)")
        else:
            print("Rock smashes scissors! You lose. :(")

    play_again = input("Play again?: ")
    if play_again.lower() != "yes":
        break
# Out:
# Enter a choice (rock, paper, scissors):  rock
# You chose rock, computer chose scissors.
#
# Rock smashes scissors! You win! :)
# Play again?:  no

# %% [markdown]
# # Random Number Generator

# %%
#importing "random" for random operations
import random;
#using random.randint() to generate a random number between 0 and 1000000
print(random.randint(0, 1000000))
# Out:
# 800351

# %% [markdown]
# # Useless Hack

# %%
#importing time module
import time

#Asking for players name
name = input("What's your name?")

print ("Hello, " + name,"!")

Yn = input("Are you ready to play hangman?")

#Wait 1 second
time.sleep(1)

print ("Start guessing...")
time.sleep(0.5)
#Strawberry is set as the word to guess. You can select any word to play with. 
word = ("benji")

#Creates an variable with an empty value
guesses = ''

#Determines the number of turns allowed before you lose
turns = 10

#Create a while loop

#Check if the turns are more than zero
while turns > 0:         

    #Counter that starts with zero
    failed = 0             

    #For every character in the word    
    for char in word:      

    #See if the letter is in the players guess
        if char in guesses:    
    
        #then print that character
            print (char,end=""),    

        else:
    
        #If not found, print a dash
            print ("_",end=""),     
       
        #and increase the failed counter by one
            failed += 1    

    #If failed is equal to zero

    #Print You Won!
    if failed == 0:        
        print ("You won!")
    #Exit script
        break            
    #Ask player to guess a letter
    guess = input("Guess a letter:") 

    #Set the players guess to guesses
    guesses += guess                    

    #If the guess is not found in the word
    if guess not in word:  
 
     #turn counter decreases by 1
        turns -= 1        
 
    #Print wrong when incorrectly answered
        print ("Wrong!!!")  
 
    #Tells the player how many turns they have left
        print ("You have", + turns, 'more guesses.' )
 
    #If the turns are equal to zero
        if turns == 0:           
    
        #print "You Lose"
            print ("You Lose..."  )
# Out:
# What's your name? mia
# Hello, mia !
# Are you ready to play hangman? yes
# Start guessing...
# _____
# Guess a letter: m
# Wrong!!!
# You have 9 more guesses.
# _____
# Guess a letter: a
# Wrong!!!
# You have 8 more guesses.
# _____
# Guess a letter: i
# ____i
# Guess a letter: o
# Wrong!!!
# You have 7 more guesses.
# ____i
# Guess a letter: l
# Wrong!!!
# You have 6 more guesses.
# ____i
# Guess a letter: r
# Wrong!!!
# You have 5 more guesses.
# ____i
# Guess a letter: d
# Wrong!!!
# You have 4 more guesses.
# ____i
# Guess a letter: p
# Wrong!!!
# You have 3 more guesses.
# ____i
# Guess a letter: b
# b___i
# Guess a letter: e
# be__i
# Guess a letter: n
# ben_i
# Guess a letter: j
# benjiYou won!

# %% [markdown]
# # Hack with ChatGPT
# **I asked ChatGPT to generate code for a calculator in Python**

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y != 0:
        return x / y
    else:
        return "Cannot divide by zero"

while True:
    print("Select operation:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    print("5. Exit")

    choice = input("Enter choice (1/2/3/4/5): ")

    if choice == '5':
        print("Exiting the calculator. Goodbye!")
        break

    if choice in ('1', '2', '3', '4'):
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))

        if choice == '1':
            print(num1, "+", num2, "=", add(num1, num2))

        elif choice == '2':
            print(num1, "-", num2, "=", subtract(num1, num2))

        elif choice == '3':
            print(num1, "*", num2, "=", multiply(num1, num2))

        elif choice == '4':
            result = divide(num1, num2)
            print(num1, "/", num2, "=", result)

    else:
        print("Invalid Input. Please enter a valid choice.")
# Out:
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Enter choice (1/2/3/4/5):  1
# Enter first number:  1
# Enter second number:  2
# 1.0 + 2.0 = 3.0
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Invalid Input. Please enter a valid choice.
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Enter choice (1/2/3/4/5):  5
# Exiting the calculator. Goodbye!
# Enter choice (1/2/3/4/5):  5

# %% [markdown]
# # Finding and Using Libraries

# %%
# Required python moduldes for opening FITS files and plotting
import numpy as np
import os
import os.path as op
import glob

import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import gridspec
import matplotlib.colors as mcolors

from astropy.io import fits

from astropy.table import Table, hstack
import astropy.units as u
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS

from astropy.visualization import make_lupton_rgb, ZScaleInterval

from astropy.coordinates import SkyCoord  # High-level coordinates
from astropy.coordinates import ICRS, Galactic, FK4, FK5  # Low-level frames
from astropy.coordinates import Angle, Latitude, Longitude  # Angles

# %%
# %matplotlib inline

# %%
version = 'v3.2' # Change to latest version   
source_table = Table.read(op.join('/kaggle/input/hetdexescv/hetdex_sc1_v3.2.ecsv'.format(version))) 

# Column Info
source_table.info
# Out:
# <Table length=232650>
#      name      dtype          unit                                       description                                 n_bad
# ------------- ------- ------------------- -------------------------------------------------------------------------- ------
#   source_name   str26                                                                         HETDEX IAU designation      0
#     source_id   int64                                                                       HETDEX Source Identifier      0
#        shotid   int64                                             integer represent observation ID: int( date+obsid)      0
#            RA float32                 deg                                       source_id right ascension (ICRS deg)      0
#           DEC float32                 deg                                           source_id declination (ICRS deg)      0
# ...

# %%
hetdexdf = source_table.to_pandas()
hetdexdf
# Out:
#                        source_name      source_id       shotid          RA  \
# 0       HETDEX J005604.29+000032.4  2140300000011  20181014010   14.017778
# 1       HETDEX J005604.29+000032.4  2140300000011  20180113006   14.017778
# 2       HETDEX J142914.44+510014.2  2140100002040  20190504015  217.310181
# 3       HETDEX J140222.64+510107.6  2140300000110  20180223010  210.594330
# 4       HETDEX J011603.95-004509.7  2140100192799  20191224010   19.016335
# ...                            ...            ...          ...         ...
# 232645  HETDEX J110313.30+511646.4  2140100000297  20190501017  165.805222
# 232646  HETDEX J161107.47+534208.0  2140100061927  20200527024  242.781128
# 232647  HETDEX J125640.42+515940.8  2140000047179  20190403022  194.168396
# 232648  HETDEX J140135.95+515711.7  2140000001451  20190504027  210.399796
# 232649  HETDEX J004905.92-003134.5  2140000003629  20191006024   12.274647
#
# ...

# %%
RA=hetdexdf.RA*u.deg
DEC=hetdexdf.DEC*u.deg

spacecoord=SkyCoord(RA, DEC, frame='icrs', unit='deg')
#coordarray = skycoord(ra column, dec column, icrsframe, in degrees)
#SkyCoord is the library and command to make coords

spacecoord

#We are going to type in the 3 points of interest
#COMAP overview Looking at +/-1.5 degrees around each of these three points 
COMAP_point_one = SkyCoord(ra='01h41m44.4s', dec='00d00m00s')
COMAP_point_two = SkyCoord(ra='11h20m00s', dec='52d30m00s')
COMAP_point_three = SkyCoord(ra='15h04m00s', dec='55d00m00s')

tol=1.5*u.deg
#this is how far away from the point we are willing to look

#new array = coordinate list.separation(how far from this planet)
sep_point_one=spacecoord.separation(COMAP_point_one)
#create an array, of the distance each of our coords is from
#the point in space we care about

#we are going index cut out) the data that is within our 
#tolerance, so we ONLY have data within 1.5 degrees of the point 
good_idx_one=np.where(sep_point_one<tol)[0]
#specifically, its cutting out the 'locations' of the data hence, np.where 
#this new data set says rows #1, 7, 15, 22 all have good data

field_one_df=hetdexdf.iloc[good_idx_one]
#create a new dataframe from our space dataframe with the rows cut out (iloc)
#of the good rows of data] only (data in range)

field_one_df

sep_point_two=spacecoord.separation(COMAP_point_two)
good_idx_two=np.where(sep_point_two<tol)[0]
field_two_df=hetdexdf.iloc[good_idx_two]

sep_point_three=spacecoord.separation(COMAP_point_three)
good_idx_three=np.where(sep_point_three<tol)[0]
field_three_df=hetdexdf.iloc[good_idx_three]

#pd. concat (df1, df2, df3) combines several dataframes together) 
combined_df=pd.concat((field_one_df, field_two_df, field_three_df))
combined_df
# Out:
#                        source_name      source_id       shotid          RA  \
# 30      HETDEX J013604.69-002806.4  2140100039333  20191222014   24.019552
# 49      HETDEX J014008.26-000242.9  2140100039311  20200118009   25.034407
# 99      HETDEX J014224.09+002702.3  2140100039505  20190105013   25.600368
# 125     HETDEX J014503.64-000345.6  2140100039569  20181011010   26.265146
# 141     HETDEX J014008.40-001136.8  2140100039585  20180822020   25.034983
# ...                            ...            ...          ...         ...
# 231520  HETDEX J150219.28+533546.2  2140100065178  20200525024  225.580338
# 231744  HETDEX J150413.47+535415.1  2140100080782  20200425016  226.056122
# 232015  HETDEX J150300.94+534405.7  2140000034212  20200525024  225.753937
# 232188  HETDEX J150544.86+535755.7  2140100004195  20200524025  226.436920
# 232642  HETDEX J145908.30+534511.7  2140100015077  20200521024  224.784576
#
# ...

# %%
print(combined_df)
# Out:
#                        source_name      source_id       shotid          RA  \
# 30      HETDEX J013604.69-002806.4  2140100039333  20191222014   24.019552
# 49      HETDEX J014008.26-000242.9  2140100039311  20200118009   25.034407
# 99      HETDEX J014224.09+002702.3  2140100039505  20190105013   25.600368
# 125     HETDEX J014503.64-000345.6  2140100039569  20181011010   26.265146
# 141     HETDEX J014008.40-001136.8  2140100039585  20180822020   25.034983
# ...                            ...            ...          ...         ...
# 231520  HETDEX J150219.28+533546.2  2140100065178  20200525024  225.580338
# 231744  HETDEX J150413.47+535415.1  2140100080782  20200425016  226.056122
# 232015  HETDEX J150300.94+534405.7  2140000034212  20200525024  225.753937
# 232188  HETDEX J150544.86+535755.7  2140100004195  20200524025  226.436920
# 232642  HETDEX J145908.30+534511.7  2140100015077  20200521024  224.784576
#
# ...

# %%
hetdexs_xaxis = combined_df['z_hetdex']

print(hetdexs_xaxis)

hetdexs_yaxis = combined_df['sn']

print(hetdexs_yaxis)
# Out:
# 30       -1.000000
# 49       -1.000000
# 99       -1.000000
# 125      -1.000000
# 141      -1.000000
#             ...
# 231520    3.426397
# 231744    3.441118
# 232015    3.457100
# 232188    3.466329
# 232642    3.703000
# Name: z_hetdex, Length: 10966, dtype: float32
# 30              NaN
# 49              NaN
# 99              NaN
# 125             NaN
# 141             NaN
#             ...
# 231520     6.080000
# 231744     6.630000
# 232015    26.110001
# 232188     6.130000
# 232642     6.060000
# Name: sn, Length: 10966, dtype: float32

# %%
fig, hetdexs = plt.subplots()
hetdexs.scatter(
    x = hetdexs_xaxis, 
    y = hetdexs_yaxis, 
    s = 20 ,
    c = 'violet',
    edgecolors = 'purple',
    label = 'Data Points')

hetdexs.set_ylim(0,80)
hetdexs.set_xlim(1e-3, 1e+1 )
hetdexs.set_xscale('log')
hetdexs.set_xlabel('Z_Hetdex')
hetdexs.set_ylabel('Sn')
hetdexs.set_title("COMAP Regions 1, 2, & 3: Sn vs. Z_hetdex")
hetdexs.legend()
